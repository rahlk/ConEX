# %% [markdown]
# ## Large

# %% [markdown]
# ### 1.  Data Formatting

# %%
import matplotlib.pyplot as plt
from numpy import random 
import pandas as pd
from pdb import set_trace
from datetime import datetime
import numpy as np
import seaborn as sns; sns.set()
import matplotlib
import matplotlib.ticker as ticker


# --- Configure seaborn ---
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
sns.set_style({'font.family': 'Helvetica 400'})
sns.set_style("ticks")
sns.set_context("poster", font_scale=1.75, rc={"lines.linewidth": 2.5})
colors = ["pale red", "windows blue", "amber", "dusty purple", "amber", "faded green"]
sns.set_palette(sns.xkcd_palette(colors))


small = pd.read_csv('hadoop_small_results.csv')
small.columns = ['iter', 'date', 'time', 'conf', 'perf']
small['runtime'] = small.perf.apply(lambda x: int(x))

chart_data = pd.DataFrame()
top__1 = small['runtime'].values / 60
top__1 = top__1.tolist()
numel_top__1 = len(top__1)

with open('wc_scale_up_small_to_large.txt', 'r') as f:
    large_scaleup = list(map(lambda x: x/600, map(int, f.read().splitlines())))

top_50 = top__1 + large_scaleup[1:] 
top_50.append(min(large_scaleup))
numel_top_50 = len(top_50)

for i in range(numel_top_50 - numel_top__1):
    top__1.append(large_scaleup[1])

baseline = 1000 * [large_scaleup[0]]

for j in range(len(baseline) - numel_top_50):
    top_50.append(top_50[-1])
    top__1.append(top__1[-1])

chart_data = []
for one, fifty, baseline in zip(top__1, top_50, baseline):
    chart_data.append([one, fifty, baseline])

chart_data = pd.DataFrame(chart_data)
chart_data.columns = ['Top-1', 'Top-50', 'Baseline']
chart_data = chart_data.cumsum()
chart_data /= 3600
chart_data.to_csv('trade_off_large.csv', index_label='Run')

# --- Stack dataframe to plot --- #
chart_data = chart_data.stack().reset_index()
chart_data.columns = ['Runs', 'Type', 'Runtime']

# %% [markdown]
# ### 2.  Plotting

# %%
ax = sns.lineplot(x="Runs", y="Runtime", hue="Type", data=chart_data)
ax.legend_.remove()
ax.set_xlim(0, 1020)
ax.xaxis.set_major_locator(ticker.MultipleLocator(250))
ax.yaxis.set_major_locator(ticker.MultipleLocator(50))
sns.despine(offset=10, trim=True)
ax.set_title("Large")
plt.savefig("large.pdf", dpi=400, bbox_inches='tight', pad_inches=0)
plt.show()
plt.clf()

# %% [markdown]
# ## Huge

# %% [markdown]
# ### 1.  Data Formatting

# %%
import matplotlib.pyplot as plt
from numpy import random 
import pandas as pd
from pdb import set_trace
from datetime import datetime
import numpy as np
import seaborn as sns; sns.set()
import matplotlib
import matplotlib.ticker as ticker


# --- Configure seaborn ---
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
sns.set_style({'font.family': 'Helvetica 400'})
sns.set_style("ticks")
sns.set_context("poster", font_scale=1.75, rc={"lines.linewidth": 2.5})
colors = ["pale red", "windows blue", "amber", "dusty purple", "amber", "faded green"]
sns.set_palette(sns.xkcd_palette(colors))


small = pd.read_csv('hadoop_small_results.csv')
small.columns = ['iter', 'date', 'time', 'conf', 'perf']
small['runtime'] = small.perf.apply(lambda x: int(x))

chart_data = pd.DataFrame()
top__1 = small['runtime'].values / 60
top__1 = top__1.tolist()
numel_top__1 = len(top__1)

with open('wc_scale_up_small_to_huge.txt', 'r') as f:
    huge_scaleup = list(map(lambda x: x/600, map(int, f.read().splitlines())))

top_50 = top__1 + huge_scaleup[1:] 
top_50.append(min(huge_scaleup))
numel_top_50 = len(top_50)

for i in range(numel_top_50 - numel_top__1):
    top__1.append(huge_scaleup[1])

baseline = 1000 * [huge_scaleup[0]]

for j in range(len(baseline) - numel_top_50):
    top_50.append(top_50[-1])
    top__1.append(top__1[-1])

chart_data = []
for one, fifty, baseline in zip(top__1, top_50, baseline):
    chart_data.append([one, fifty, baseline])

chart_data = pd.DataFrame(chart_data)
chart_data.columns = ['Top-1', 'Top-50', 'Baseline']
chart_data = chart_data.cumsum()
chart_data /= 3600
chart_data.to_csv('trade_off_huge.csv', index_label='Run')

# --- Stack dataframe to plot --- #
chart_data = chart_data.stack().reset_index()
chart_data.columns = ['Runs', 'Type', 'Runtime']

# %% [markdown]
# ### 2.  Plotting

# %%
ax = sns.lineplot(x="Runtime", y="Runs", hue="Type", data=chart_data)
ax.legend_.remove()
ax.set_xlim(0, 1020)
ax.xaxis.set_major_locator(ticker.MultipleLocator(250))
ax.yaxis.set_major_locator(ticker.MultipleLocator(500))
sns.despine(offset=10, trim=True)
ax.set_title("Huge")
plt.savefig("Huge.pdf", dpi=400, bbox_inches='tight', pad_inches=0)
plt.show()
plt.clf()
